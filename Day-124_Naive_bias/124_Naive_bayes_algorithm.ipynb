# %%
import numpy as np
import pandas as pd
import io

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-3f56ba55-d61d-4ee6-bab9-3ba5927263e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f56ba55-d61d-4ee6-bab9-3ba5927263e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(upload['PlayTennis.csv']))

# %%
df
# Out:
#      Outlook Temperature Humidity    Wind Play Tennis
# 0      Sunny         Hot     High    Weak          No
# 1      Sunny         Hot     High  Strong          No
# 2   Overcast         Hot     High    Weak         Yes
# 3       Rain        Mild     High    Weak         Yes
# 4       Rain        Cool   Normal    Weak         Yes
# 5       Rain        Cool   Normal  Strong          No
# 6   Overcast        Cool   Normal  Strong         Yes
# 7      Sunny        Mild     High    Weak          No
# 8      Sunny        Cool   Normal    Weak         Yes
# 9       Rain        Mild   Normal    Weak         Yes
# 10     Sunny        Mild   Normal  Strong         Yes
# 11  Overcast        Mild     High  Strong         Yes
# 12  Overcast         Hot   Normal    Weak         Yes
# 13      Rain        Mild     High  Strong          No

# %%
# let's first calculate probabilty of yes or no
df['Play Tennis'].value_counts()
# Out:
# Play Tennis
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py = 9/14
pn = 5/14

# %%
py,pn
# Out:
# (0.6428571428571429, 0.35714285714285715)

# %%
# Probablity for the Outlook columns

pd.crosstab(df['Outlook'],df['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Outlook
# Overcast      0    4
# Rain          2    3
# Sunny         3    2

# %%
pon = 0
prn = 2/5
psn = 3/5

poy = 4/9
pry = 3/9
Psy = 2/9

# %%
# Probablity for the Temperature columns

pd.crosstab(df['Temperature'],df['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Temperature
# Cool          1    3
# Hot           2    2
# Mild          2    4

# %%
pcn = 1/5
phn = 2/5
pmn = 2/5

pcy = 3/9
phy = 2/9
pmy = 4/9

# %%
# Probablity for the Humidity columns

pd.crosstab(df['Humidity'],df['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Humidity
# High          4    3
# Normal        1    6

# %%
phhn = 4/5
pnn = 1/5

phhy = 3/9
pny = 6/9

# %%
#  Probablity for the wind columns

pd.crosstab(df['Wind'],df['Play Tennis'])
# Out:
# Play Tennis  No  Yes
# Wind
# Strong        3    3
# Weak          2    6

# %%
pwstrongn = 3/5
pwweakn = 2/5

pwstrongy = 3/9
pwweaky = 6/9

# %%
# outlook = sunny , temprature = Hot , humidity = High, wind = weak

Pyes = py*Psy*phy*phhy*pwweaky

# %%
print(Pyes)
# Out:
# 0.007054673721340388

# %%
# probability of no

Pno = pn*psn*phn*phhn*pwweakn

# %%
print(Pno)
# Out:
# 0.02742857142857143

# %% [markdown]
# ## Conclusion : here P(yes) < P(NO) so tennis weill be not played on that day
